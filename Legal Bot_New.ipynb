# %% [markdown]
# ## ***Installing Dependencies***

# %%
! pip install -U langchain-community

# %%
! pip install llama-cpp-python langchain PyPDF2 pypdf chromadb sentence-transformers ctransformers langchain_groq

# %% [markdown]
# ## ***Importing Dependencies***

# %%
import os
import warnings
warnings.filterwarnings("ignore")
from pypdf import PdfReader as PyPdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import SystemMessage, HumanMessage
from langchain.chains import RetrievalQA
from langchain_groq import ChatGroq

# %% [markdown]
# ## ***API Configuration***

# %%
os.environ["GROQ_API_KEY"] = "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"

# %% [markdown]
# ## ***Initializing GROQ API Model - Mixtral-8x7b-32768***

# %%
llm_groq = ChatGroq(model_name="mixtral-8x7b-32768", api_key=os.getenv("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"))
#llm_groq = ChatGroq(model_name="gemma2-9b-it", api_key=os.getenv("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"))
#llm_groq = ChatGroq(model_name="Gemma 7B", api_key=os.getenv("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"))
#llm_groq = ChatGroq(model_name="Falcon 7B", api_key=os.getenv("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"))

# %% [markdown]
# ## ***Preprocessing Layer***

# %% [markdown]
# #### ***Document Reading***

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        reader = PyPdfReader(pdf_path)
        text = "\n".join([page.extract_text() for page in reader.pages if page.extract_text()])
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {e}")
    return text

pdf_files = {
    "doc1": "Project_input_1.pdf",
    "doc2": "Project_input_2.pdf"
}
documents = {name: extract_text_from_pdf(path) for name, path in pdf_files.items()}
print(f"{len(documents)} Document Loaded")
# Out:
# 2 Document Loaded

# %% [markdown]
# ## ***Building a RAG Pipeline (Summarization  - Legal Chat Bot  -FAQs)***

# %% [markdown]
# ### ***Semantic Layer***

# %% [markdown]
# #### ***Step 1: Chunking the text in the Documents***

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.create_documents(list(documents.values()))
print("Chunking Completed Successfully")
# Out:
# Chunking Completed Successfully

# %% [markdown]
# #### ***Step 2: Creating Vector Embeddings***

# %%
#embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
embedding_model = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

documents_text = [chunk.page_content for chunk in chunks]
document_embeddings = embedding_model.embed_documents(documents_text)
# Out:
# <ipython-input-10-9573e3e77b6b>:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# import shutil
# shutil.rmtree("./chroma_db", ignore_errors=True)

# %% [markdown]
# #### ***Step 3: Storing Embeddings to Chroma DB***

# %%
#vector_db = FAISS.from_texts(documents_text, embedding_model)
vector_db = Chroma.from_texts(documents_text, embedding_model, persist_directory="./chroma_db")
print("Documents Embedded and Stored Successfully")
# Out:
# Documents Embedded and Stored Successfully

# %% [markdown]
# ### ***Functional Layer***

# %% [markdown]
# #### ***Step 1: Summarization of Legal Preceddings***

# %%
def summarize_legal_document(doc_text, chunk_size=2000):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=200)
    chunks = text_splitter.split_text(doc_text)

    summaries = []
    for i, chunk in enumerate(chunks):
        print(f"Summarizing chunk {i+1}/{len(chunks)}...")

        prompt = (
            "You are an AI legal expert specializing in legal compliance and case law analysis. "
            "Summarize the legal documents in a crisp and structured case history . "
            " The Case story should highlighting key legal arguments, precedents and final judgments in a bulleted format. "
            "Use a professional and legal tone when necessary, focusing on clarity and brevity.\n\n"
            f"### Legal Document Chunk {i+1}:\n{chunk}\n\n"
            " Provide a structured legal summary below:"
        )

        try:
            response = llm_groq.invoke([HumanMessage(content=prompt)])
            summaries.append(response.content.strip())

        except Exception as e:
            print(f"Error summarizing chunk {i+1}: {e}")
            #summaries.append("Summary unavailable for this section.")

    return "\n\n".join(summaries)

case_histories = {name: summarize_legal_document(text) for name, text in documents.items()}


# # Older Prompt
# def summarize_legal_document(doc_text, chunk_size=2000):
#     # Step 1: Chunk the text to prevent exceeding Groq API token limits
#     text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=200)
#     chunks = text_splitter.split_text(doc_text)

#     summaries = []

#     # Step 2: Process each chunk separately
#     for i, chunk in enumerate(chunks):
#         print(f"🔹 Summarizing chunk {i+1}/{len(chunks)}...")  # Progress tracking

#         prompt = (
#             "You are an AI legal expert. Summarize the following legal document into a structured case history:\n\n"
#             f"{chunk}\n\n"
#             "Provide key details such as case background, legal arguments, precedents, and final judgments."
#         )

#         try:
#             response = llm_groq.invoke([HumanMessage(content=prompt)])
#             summaries.append(response.content.strip())

#         except Exception as e:
#             print(f"Error summarizing chunk {i+1}: {e}")
#             summaries.append("Summary unavailable for this section.")

#     return "\n\n".join(summaries)  # Combine all chunk summaries

# # Step 3: Summarizing each document in the dataset
# case_histories = {name: summarize_legal_document(text) for name, text in documents.items()}

# # Step 4: Print summarized case histories
# print("📌 Summarized Case Histories:")
# for name, summary in case_histories.items():
#     print(f"\n🔹 {name}:\n{summary}")
# Out:
# Summarizing chunk 1/7...
# Error summarizing chunk 1: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 2/7...
# Error summarizing chunk 2: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 3/7...
# Error summarizing chunk 3: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 4/7...
# Error summarizing chunk 4: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 5/7...
# Error summarizing chunk 5: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 6/7...
# Error summarizing chunk 6: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 7/7...
# Error summarizing chunk 7: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 1/94...
# Error summarizing chunk 1: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 2/94...
# Error summarizing chunk 2: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 3/94...
# Error summarizing chunk 3: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 4/94...
# Error summarizing chunk 4: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 5/94...
# Error summarizing chunk 5: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 6/94...
# Error summarizing chunk 6: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 7/94...
# Error summarizing chunk 7: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 8/94...
# Error summarizing chunk 8: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 9/94...
# Error summarizing chunk 9: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 10/94...
# Error summarizing chunk 10: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 11/94...
# Error summarizing chunk 11: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 12/94...
# Error summarizing chunk 12: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 13/94...
# Error summarizing chunk 13: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 14/94...
# Error summarizing chunk 14: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 15/94...
# Error summarizing chunk 15: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 16/94...
# Error summarizing chunk 16: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 17/94...
# Error summarizing chunk 17: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 18/94...
# Error summarizing chunk 18: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 19/94...
# Error summarizing chunk 19: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 20/94...
# Error summarizing chunk 20: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 21/94...
# Error summarizing chunk 21: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 22/94...
# Error summarizing chunk 22: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 23/94...
# Error summarizing chunk 23: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 24/94...
# Error summarizing chunk 24: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 25/94...
# Error summarizing chunk 25: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 26/94...
# Error summarizing chunk 26: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 27/94...
# Error summarizing chunk 27: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 28/94...
# Error summarizing chunk 28: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 29/94...
# Error summarizing chunk 29: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 30/94...
# Error summarizing chunk 30: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 31/94...
# Error summarizing chunk 31: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 32/94...
# Error summarizing chunk 32: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 33/94...
# Error summarizing chunk 33: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 34/94...
# Error summarizing chunk 34: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 35/94...
# Error summarizing chunk 35: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 36/94...
# Error summarizing chunk 36: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 37/94...
# Error summarizing chunk 37: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 38/94...
# Error summarizing chunk 38: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 39/94...
# Error summarizing chunk 39: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 40/94...
# Error summarizing chunk 40: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 41/94...
# Error summarizing chunk 41: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 42/94...
# Error summarizing chunk 42: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 43/94...
# Error summarizing chunk 43: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 44/94...
# Error summarizing chunk 44: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 45/94...
# Error summarizing chunk 45: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 46/94...
# Error summarizing chunk 46: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 47/94...
# Error summarizing chunk 47: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 48/94...
# Error summarizing chunk 48: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 49/94...
# Error summarizing chunk 49: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 50/94...
# Error summarizing chunk 50: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 51/94...
# Error summarizing chunk 51: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 52/94...
# Error summarizing chunk 52: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 53/94...
# Error summarizing chunk 53: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 54/94...
# Error summarizing chunk 54: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 55/94...
# Error summarizing chunk 55: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 56/94...
# Error summarizing chunk 56: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 57/94...
# Error summarizing chunk 57: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 58/94...
# Error summarizing chunk 58: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 59/94...
# Error summarizing chunk 59: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 60/94...
# Error summarizing chunk 60: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 61/94...
# Error summarizing chunk 61: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 62/94...
# Error summarizing chunk 62: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 63/94...
# Error summarizing chunk 63: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 64/94...
# Error summarizing chunk 64: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 65/94...
# Error summarizing chunk 65: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 66/94...
# Error summarizing chunk 66: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 67/94...
# Error summarizing chunk 67: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 68/94...
# Error summarizing chunk 68: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 69/94...
# Error summarizing chunk 69: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 70/94...
# Error summarizing chunk 70: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 71/94...
# Error summarizing chunk 71: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 72/94...
# Error summarizing chunk 72: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 73/94...
# Error summarizing chunk 73: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 74/94...
# Error summarizing chunk 74: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 75/94...
# Error summarizing chunk 75: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 76/94...
# Error summarizing chunk 76: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 77/94...
# Error summarizing chunk 77: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 78/94...
# Error summarizing chunk 78: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 79/94...
# Error summarizing chunk 79: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 80/94...
# Error summarizing chunk 80: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 81/94...
# Error summarizing chunk 81: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 82/94...
# Error summarizing chunk 82: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 83/94...
# Error summarizing chunk 83: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 84/94...
# Error summarizing chunk 84: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 85/94...
# Error summarizing chunk 85: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 86/94...
# Error summarizing chunk 86: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 87/94...
# Error summarizing chunk 87: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 88/94...
# Error summarizing chunk 88: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 89/94...
# Error summarizing chunk 89: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 90/94...
# Error summarizing chunk 90: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 91/94...
# Error summarizing chunk 91: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 92/94...
# Error summarizing chunk 92: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 93/94...
# Error summarizing chunk 93: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# Summarizing chunk 94/94...
# Error summarizing chunk 94: Error code: 400 - {'error': {'message': 'The model `mixtral-8x7b-32768` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}

# %%
def dict_to_bullets(case_histories):
    #return "\n".join(f"• {key}: {value}" for key, value in case_histories.items())
    return "\n".join(f"• {value}" for value in case_histories.values())
print(dict_to_bullets(case_histories))
# Out:
# • ## Case History: Galvez v. The State (A24A1657)
#
# **Parties:**
#
# * Appellant: Billy Milton Galvez
# * Appellee: The State of Georgia
#
# **Charges:**
#
# * Malice murder (later reduced to voluntary manslaughter)
# * Aggravated assault (one charge challenged)
# * Possession of a firearm during the commission of a felony
#
# **Facts:**
#
# * On July 5, 2020, Alejandro Ramirez was shot and killed at Fusion Event Hall.
# * Appellant Billy Milton Galvez was present at the scene.
# * Evidence shows Galvez, his girlfriend Jennifer Cardona-Rodriguez, and friend Jorge Avila consumed alcohol and fired Galvez's handgun before arriving at Fusion.
# * An altercation occurred between Cardona-Rodriguez and Ramirez at Fusion.
#
# **Legal Arguments:**
#
# * **Appellant's Argument 1:** The trial court erred by overruling Galvez's demurrer challenging the sufficiency of the indictment as to one of the aggravated assault charges.
# * **Appellant's Argument 2:** The trial court erred in its jury instructions regarding the definition of aggravated assault.
#
# **Precedents:**
#
# * No specific precedents are mentioned in the provided document excerpt.
#
# **Judgment:**
#
# * The Court of Appeals of Georgia affirmed the trial court's decision.
# * Galvez's conviction for voluntary manslaughter, aggravated assault, and possession of a firearm during the commission of a felony stands.
#
# **Notes:**
#
# * This document excerpt does not provide details regarding the court's reasoning for affirming the judgment. Further legal documents would be needed to fully analyze the court's arguments and legal basis for its decision.
#
# ## Case History Summary: State v. Galvez
#
# **Facts:**
#
# *  On July 5, 2020, an altercation occurred at Fusion nightclub between the defendant, Galvez, and the victim, Ramirez.
# *  Galvez's girlfriend, Cardona-Rodriguez, and a friend, Avila, were present.
# *  Cardona-Rodriguez claims Ramirez shoved her, leading to an argument.
# *  Galvez returned to Fusion with Cardona-Rodriguez and Avila, after which he shot Ramirez multiple times, resulting in Ramirez's death.
# *  Eight 9mm casings were found at the scene.
#
# **Charges:**
#
# *  Malice murder (Count 1)
# *  Felony murder (Count 2) predicated on aggravated assault
# *  Two counts of aggravated assault (Counts 3 and 4)
# *  Three counts of possession of a firearm during the commission of a felony (Counts 5, 6, and 7)
#
# **Key Legal Arguments:**
#
# *  **Defendant's Demurrer:** Galvez filed a general demurrer, arguing that the indictment failed to sufficiently charge him with aggravated assault.
#
# **Procedural History:**
#
# *  A hearing was held in the trial court regarding the demurrer.
#
# **Outcome:**
#
# *  The summary provided does not include the trial court's ruling on the demurrer.
#
#
# **Precedent & Analysis:**
#
# *  The case hinges on the definition and application of "aggravated assault" under relevant state law.
# *  The court's ruling on the demurrer will likely focus on whether the indictment accurately alleges the elements of aggravated assault as required for the felony murder charge.
#
#
# **Notes:**
#
# * This summary is incomplete due to the lack of information regarding the trial court's ruling on the demurrer.
# *  A complete case history would require further details about subsequent proceedings, arguments presented by both parties, and the final judgment.
#
# ## Case History Summary: State v. Galvez
#
# **Defendant:** Galvez
#
# **Charges:** Aggravated assault, felony murder, voluntary manslaughter (among others)
#
# **Key Legal Arguments:**
#
# * **Demurrer:** Galvez argued that the indictment for aggravated assault (Count 3) was insufficient because it did not specify whether the assault involved a violent injury or the apprehension of immediate violent injury.
# * **Sufficiency of Indictment:** Galvez's argument centered on the requirement that an indictment enable the defendant to prepare a defense and protect against double jeopardy. He claimed the indictment lacked clarity regarding the specific type of assault alleged.
#
# **Precedent Cited:**
#
# * **Issa v. State:** This case established the standard for evaluating indictment sufficiency, stating that an indictment is sufficient if it states the offense in clear language that allows jurors to understand the nature of the charge.
#
# **Trial Proceedings:**
#
# * **Verdict:** The jury found Galvez guilty of aggravated assault (Count 3), guilty of voluntary manslaughter (Count 2, a lesser included offense of felony murder), and not guilty on other counts.
# * **Motion for New Trial:** Galvez filed a motion for new trial, which was denied by the trial court.
#
# **Final Judgment:**
#
# * The trial court's denial of Galvez's demurrer and motion for new trial were upheld.
#
#
# **Note:** This summary focuses on the specific legal arguments and judgments related to the demurrer and motion for new trial. It does not encompass the entirety of the case details.
#
# ## Case History: Issa v. State, 340 Ga. App. 327 (2017)
#
# **Facts:**  Defendant Galvez was indicted for aggravated assault with a deadly weapon.  He challenged the indictment's sufficiency, arguing it failed to adequately describe the assault.
#
# **Legal Arguments:**
#
# * **Sufficiency of Indictment:** The State argued that the indictment was sufficient because it tracked the language of the relevant statute (OCGA § 16-5-21 (a) (2)) and sufficiently apprised Galvez of the charges against him.
# * **Specificity of Allegations:** Galvez argued the indictment was void because it did not specify the manner in which he committed simple assault (attempting violent injury or placing another in reasonable apprehension of immediate violent injury).
#
# **Precedents:**
#
# *  The court cited *Issa v. State* to establish the test for sufficiency of an indictment: whether it contains the elements of the offense and apprises the defendant of the charges.
# *  The court also cited *State v. Austin* to support the proposition that an indictment substantially in the language of the Code is sufficient in form and substance.
#
# **Final Judgments:**
#
# * **Indictment Upheld:** The court found the indictment sufficient because it tracked the language of the statute and adequately informed Galvez of the charges against him.
# * **Specificity Argument Rejected:** The court rejected Galvez's argument regarding the specificity of the assault allegation, finding it without merit.
#
#
# **Conclusion:** The court upheld the indictment against Galvez for aggravated assault, finding it sufficiently specific and in compliance with legal requirements.
#
# ## Case Summary: Galvez v. State
#
# **Key Legal Arguments:**
#
# * **Sufficiency of Indictment:** The defendant (Galvez) argued that the indictment charging aggravated assault was insufficient because it did not specify the manner in which the simple assault was committed.
# * **Jury Instruction on Simple Assault:** Galvez argued that the trial court erred by instructing the jury on two methods of committing simple assault, neither of which was charged in the indictment.
#
# **Precedent:**
#
# * **Chase v. State, 277 Ga. 636 (1) (592 SE2d 656) (2004):** The Georgia Supreme Court held that an indictment for aggravated assault does not need to specify the manner of the simple assault, but must allege the aggravating aspect.
#
# **Key Findings:**
#
# * **Indictment Sufficiency:** The court found the indictment sufficient because it alleged the assault and the aggravating factor (use of a handgun), complying with the requirements set forth in Chase v. State.
# * **Jury Instruction:** The court found no reversible error in the jury instruction on simple assault, noting that defense counsel objected to the proposed instruction at the charge conference.
#
# **Final Judgment:**
#
# * The trial court's ruling overruling Galvez's demurrer to the indictment was affirmed.
# * Galvez's conviction on Count 3 was upheld.
#
# ## Case History Summary:
#
# **Case Name:**  (Missing from provided text)
#
# **Defendant:** Galvez
#
# **Charge:** Aggravated Assault
#
# **Key Legal Arguments:**
#
# * **Definition of Assault:** The prosecution argued that the assault was complete even without physical contact, as long as the victim reasonably feared immediate violent injury.  This argument relied on the legal principle that an apparent ability to inflict harm, coupled with a demonstration of violence, can constitute an assault.
# * **Burden of Proof:** The defense objected to the jury instructions, arguing that the state had not adequately established its burden of proof. The prosecution countered by demonstrating that the jury was instructed on the "beyond a reasonable doubt" standard and provided with the indictment outlining the specific allegations.
#
# **Precedents Cited:**
#
# * **Manning v. State, 303 Ga. 723, 728 (4) (814 SE2d 730) (2018):**  This case establishes the standard of review for appellate courts when examining jury instructions. Appellate courts assess whether the jury was "fully and fairly instructed on the law of the case."
# * **Simpson v. State, 302 Ga. 875, 877 (2) (808 SE2d 718) (2017):** This case supports the argument that sending the indictment to the jury and instructing them on the state's burden of proof cures any potential defects in the jury instructions.
#
# **Final Judgment:**
#
# * The outcome of the case is not provided in the text.
#
#
# **Note:** This summary is based solely on the information provided in Legal Document Chunk 6.  A complete and accurate case history would require additional legal documents and factual information.
#
# ## Case History Summary:
#
# * **Case:**  Galvez v. State (Likely fictionalized for this document example)
# * **Charges:**  Voluntary manslaughter, aggravated assault (Count 3).
# * **Key Issue:**  Whether the trial court's jury instructions improperly broadened the manner in which the jury could convict Galvez of aggravated assault.
#
# * **Arguments:**
#     * **State:** The jury instructions did not impermissibly broaden the jury's options for convicting Galvez of aggravated assault.  The jury was required to find that Galvez caused Ramirez's death for the voluntary manslaughter conviction, which meant they implicitly found Galvez shot Ramirez.
#     * **Defense:** The jury instructions were flawed as they did not explicitly state that Galvez had to shoot Ramirez for a conviction on the aggravated assault charge.
#
# * **Precedent:**
#     * **Lyons v. State:**  Established that a jury's finding of guilt for voluntary manslaughter, which requires proof of death caused by the defendant, can implicitly demonstrate the defendant's act of shooting the victim.
#     * **Depriest v. State:**  Established that any potential error in jury instructions is harmless if the jury's verdict would have likely been the same regardless of the instruction.
#
# * **Judgment:**
#     * Trial court's denial of the amended motion for a new trial was affirmed.
#     * Galvez's convictions for voluntary manslaughter and aggravated assault were upheld.
#
#
#
# **Conclusion:**
#
# The court found that the jury instructions, while potentially lacking explicit language regarding the shooting element of aggravated assault, were not fundamentally flawed. The jury's conviction for voluntary manslaughter, which required proof of shooting, served as implicit evidence for the aggravated assault charge.  Therefore, any potential error in the instructions was deemed harmless.
# • ## Case History: Santaniello v. Commissioner of Correction (AC 46199)
#
# **Key Legal Arguments:**
#
# * **Petitioner's Claim:** The petitioner, Anthony Santaniello Jr., argued that his prior habeas corpus counsel, identified as "B," provided ineffective assistance of counsel. This alleged ineffectiveness stemmed from B's failure to raise specific claims in the initial habeas petition.
#
# * **Respondent's Defense:** The Commissioner of Correction, the respondent, likely defended the habeas court's judgment, arguing that B's representation was not deficient and did not prejudice Santaniello's case.
#
# **Precedent:**
#
# * The case likely hinges on the established legal framework for ineffective assistance of counsel claims, derived from the landmark Supreme Court case *Strickland v. Washington* (1984).  This case set a two-pronged test:
#
#    *  The defendant must demonstrate that their counsel's performance fell below an objective standard of reasonableness.
#    *  The defendant must prove that the deficient performance prejudiced the defense, meaning there is a reasonable probability that the outcome of the proceedings would have been different had counsel performed adequately.
#
# **Final Judgment:**
#
# * The Connecticut Appellate Court granted certification to review the habeas court's decision.
# * The outcome of the case, whether the habeas court's judgment was affirmed or reversed, is not provided in the excerpt.
#
#
# **Note:** This summary is based on the limited information provided in the document excerpt. A more comprehensive analysis would require reviewing the full case documents, including the habeas court's decision, the petitioner's appeal, and the Appellate Court's ruling.
#
# ## Case History Summary
#
# **Case:**  Petitioner v. Respondent
#
# **Issue:** Ineffective assistance of counsel claims related to the admission of jailhouse informant testimony.
#
# **Key Legal Arguments:**
#
# * **Petitioner:**
#     * His prior habeas counsel (B) was ineffective for failing to raise a *Crawford v. Washington* claim regarding the admission of statements by jailhouse informant (M) at his trial.
#     * This claim should have been raised against both trial counsel (R) and appellate counsel (S).
# * **Respondent:**
#     * B did not render ineffective assistance because:
#         * R did not perform deficiently by failing to raise the *Crawford* claim immediately after the *Crawford* decision, as its application to informant testimony was unclear at that time.
#         * S was not ineffective because she was aware of *State v. Greene* which addressed unpreserved Crawford claims, but the informant's testimony was harmless error and unlikely to have succeeded on appeal.
#
# **Precedents:**
#
# * **Crawford v. Washington (541 U.S. 36):** Establishes the Sixth Amendment right to confront witnesses, impacting the admissibility of testimonial hearsay.
# * **State v. Greene (274 Conn. 134):** Addresses the issue of unpreserved *Crawford* claims on direct appeal.
#
# **Final Judgment:**
#
# * The court rejected the petitioner's claim of ineffective assistance of counsel.
# * It held that both R and S did not perform deficiently and that any error regarding the informant's testimony was harmless.
#
# ## Case History Summary
#
# This case involves a petitioner challenging the legal representation provided by attorney B.
#
# * **Key Argument:** The petitioner argues that attorney B provided ineffective assistance by failing to raise a claim that R, another attorney involved in the case, made a tactical error at trial. This alleged error involved not asserting a violation of the petitioner's right to counsel under *Massiah v. United States* (377 U.S. 201).
# * **Massiah v. United States Precedent:**  *Massiah* established that the use of a defendant's own informant to elicit incriminating statements after the defendant has retained counsel violates the Sixth Amendment right to counsel.
# * **Attorney B's Defense:** Attorney B argues that failing to raise the *Massiah* claim was not ineffective assistance because M, the informant, had initiated contact with the state, not the state with M.
# * **Outcome:** The court ultimately rejected the petitioner's claim of ineffective assistance, finding that attorney B's decision not to raise the *Massiah* claim was a strategic one.
#
#
# **Note:** This summary is based on the limited information provided. A more comprehensive analysis would require reviewing the full legal documents.
#
# ## Santaniello v. Commissioner of Correction: Case Summary
#
# **Procedural History:**
#
# * Anthony Santaniello, Jr. filed a petition for a writ of habeas corpus in the Superior Court of Connecticut.
# * The petition was partially withdrawn, and the court ultimately denied the remaining claims.
# * Santaniello appealed the denial to the Connecticut Appellate Court, which granted certification.
#
# **Key Legal Arguments:**
#
# * **Ineffective Assistance of Counsel:** Santaniello argued that his prior habeas counsel was deficient for failing to raise two claims:
#     * **Crawford v. Washington Violation:**  His trial and appellate counsel were ineffective for failing to argue that the admission of a jailhouse informant's testimony violated his Sixth Amendment right to confrontation under *Crawford v. Washington*.
#     * **Massiah v. United States Violation:** His trial counsel was ineffective for waiving his claim that the state violated his Sixth Amendment right to counsel under *Massiah v. United States* by using a jailhouse informant to elicit incriminating statements.
#
# **Precedents Cited:**
#
# * *Crawford v. Washington*, 541 U.S. 36 (2004) - Established the Confrontation Clause's limitations on the admission of testimonial hearsay.
# * *Massiah v. United States*, 377 U.S. 201 (1964) - Held that the right to counsel attaches at the initiation of adversary judicial proceedings, prohibiting the government from using counsel-absent interrogation to elicit incriminating statements.
#
# **Final Judgment:**
#
# * The Connecticut Appellate Court affirmed the habeas court's denial of the petition.
#
#
# This summary highlights the key legal arguments, precedents, and final judgment in the case of *Santaniello v. Commissioner of Correction*.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Key Facts:**
#
# * The petitioner (Santaniello) and the victim were acquaintances.
# * On January 12, 2002, Santaniello and the victim spent time together at a pub.
# * Later that night, Santaniello entered the victim's unlocked apartment and sexually assaulted her.
#
# **Legal Arguments:**
#
# * **Petitioner's Argument:** [Not explicitly stated in the provided document excerpt. This section would typically outline the petitioner's legal arguments for challenging the conviction or sentence.]
# * **State's Argument:** [Not explicitly stated in the provided document excerpt. This section would typically outline the state's legal arguments defending the conviction or sentence.]
#
# **Precedent:**
#
# * The provided document does not explicitly cite any specific legal precedents. However, the case likely relied on general principles of criminal law, including sexual assault statutes, consent, and the standard of proof beyond a reasonable doubt.
#
# **Final Judgment:**
#
# * The habeas court's judgment was affirmed.
# * This suggests that the court found no legal basis to overturn Santaniello's criminal conviction.
#
# **Note:** This summary is based solely on the provided document excerpt and may not capture the full scope of the case.  A complete legal analysis would require reviewing the entire case record, including the trial transcript, briefs, and any relevant appellate court decisions.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# **Key Facts:**
#
# * The petitioner was charged with sexual assault, burglary, and kidnapping.
# * While incarcerated, the petitioner allegedly solicited a cellmate to kill the victim to prevent her from testifying.
# *  An undercover operation was initiated by law enforcement involving an informant and a posing "assassin."
#
# **Legal Arguments:**
#
# * The prosecution likely argued that the petitioner's solicitation of murder constituted a separate criminal offense, independent of the initial charges. They would have relied on case law defining solicitation and the elements required for conviction.
# * The defense may have argued that the petitioner's statements were not serious or constituted protected speech. They might have challenged the credibility of the informant and the undercover operation.
#
# **Precedent:**
#
# * The case would have relied on legal precedents defining solicitation of murder, entrapment, and the admissibility of evidence obtained through undercover operations.
#
# **Final Judgment:**
#
# *  The document excerpt does not provide information about the final judgment in the case. It ends with the petitioner's arrest on October 25, 2002.
#
#
# **Note:** This summary is based solely on the provided document excerpt and lacks information about the final outcome of the case.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# **Key Facts:**
#
# *  The petitioner, Santaniello, was charged with multiple offenses, including sexual assault, kidnapping, attempt to commit murder, inciting injury, and intimidating a witness.
# *  He confessed to a cellmate about his plan to have the victim killed to prevent her from testifying.
#
# **Legal Arguments:**
#
# *  **Joinder of Informations:** The petitioner argued the trial court abused its discretion by consolidating two separate informations, claiming prejudice.
# *  **Motion to Suppress:** The petitioner argued the trial court erred in denying his motion to suppress evidence.
# *  **In Camera Review:** The petitioner argued the trial court failed to conduct an in camera review of certain documents.
# *  **Postverdict Motion:** The petitioner argued the trial court improperly refused to consider his postverdict letter requesting a new trial.
#
# **Precedents:**
#
# * The summary does not explicitly mention specific legal precedents cited in the case.
#
# **Judgment:**
#
# * The Connecticut Appellate Court affirmed the trial court's judgments on direct appeal.
#
#
# **Note:** This summary is based solely on the provided text and does not encompass the full legal arguments, evidence, or reasoning behind the court's decision.
#
# ## Case History Summary
#
# This case involves a petitioner whose convictions were affirmed on direct appeal.
#
# * **Key Legal Arguments:**
#     * The petitioner argued for a new trial, citing potential injustice stemming from the joinder of informations.
# * **Precedent:**
#     * The court's decision does not explicitly cite any specific precedents.
# * **Final Judgment:**
#     * The appellate court affirmed the judgments of conviction.
#     * The court found that the joinder of informations did not result in substantial injustice.
#     * Attorney Deborah G. Stevenson, a special public defender, represented the petitioner.
#
#
# **Note:** This summary is limited by the provided document fragment. A more comprehensive analysis would require the full text of the legal documents.
#
# ## Case Summary: Santaniello v. Commissioner of Correction
#
# **Key Legal Arguments & Precedents:**
#
# * **Santaniello's initial appeal** focused on the admissibility of his statements, the denial of his motion to suppress, and the court's refusal to review documents in camera.
#     * The appellate court upheld the trial court's rulings, finding sufficient evidence to support the admission of his statements and concluding that in camera review was unnecessary given defense counsel's agreement.
# * **Santaniello's petition for a new trial** alleged newly discovered evidence in the form of testimony from another inmate, Felix Cotto, who claimed the key prosecution witness, Holeman, had fabricated his testimony.
#
# **Final Judgments:**
#
# * **Appellate Court:** Affirmed the trial court's rulings in Santaniello's direct appeal, rejecting his claims regarding the admissibility of his statements, motion to suppress, and in camera review.
# * **Connecticut Supreme Court:** Denied Santaniello's petition for certification to appeal.
# * **Trial Court (Petition for New Trial):** Denied Santaniello's petition for a new trial, finding that even if Cotto's testimony were accepted, it was unlikely to have changed the trial's outcome.
#
# **Noteworthy Points:**
#
# * Santaniello's initial appeal was represented by attorney Randolph.
# * After his direct appeal, Santaniello pursued a separate petition for a new trial with attorney William H. Paetzold.
# * A key argument in the new trial petition revolved around a letter alleging manipulation and coercion by another individual involved in the case.
#
# ## Case History Summary
#
# * **Initial Petition:** Randolph filed a petition alleging "newly discovered evidence" based on a letter.
# * **Procedural Error:** Randolph acknowledged the petition was improperly filed and should have been a civil action under Practice Book § 42-55 and General Statutes § 52-270.
# * **Withdrawal and Re-filing:** Randolph withdrew the initial petition and subsequently re-filed it as a civil action on May 6, 2004.
# * **Direct Appeal:** Randolph appealed the trial court's refusal to consider the initially filed petition.
# * **Appellate Decision:** The appellate court found Randolph's claim baseless, citing  *State v. Santaniello*, 96 Conn. App. 672–73.
#
#
# **Key Takeaways:**
#
# *  The case highlights the importance of correctly filing legal documents to ensure they are properly considered by the court.
# *  Procedural errors can be grounds for dismissal or rejection of a claim, as demonstrated by the appellate court's decision.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Core Issue:** Petitioner alleges ineffective assistance of counsel at both trial and appellate levels, and further alleges ineffective assistance of counsel in the first habeas action.
#
# **Procedural History:**
#
# * **Initial Trial:** Petitioner convicted of attempted murder.
# * **Direct Appeal:** Unsuccessful.
# * **First Habeas Action:**
#     * Petitioner alleged ineffective assistance of both trial counsel (Randolph) and appellate counsel (Stevenson).
#     * First habeas court (Cobb, J.) denied the petition.
#     * Petitioner appealed, challenging only the ineffective assistance of appellate counsel claim.
#     * Appellate Court affirmed the denial of the petition.
#     * Supreme Court denied certification to appeal.
# * **Second Habeas Action:**
#     * Petitioner alleged ineffective assistance of counsel in the first habeas action (Walter Bansley IV) for failing to raise certain claims, including:
#         * Both Randolph and Stevenson provided ineffective assistance by failing to raise a Crawford claim.
#         * Randolph provided ineffective assistance by waiving the petitioner's Massiah claim.
#     * Current appeal stems from this second habeas action.
#
# **Key Legal Arguments:**
#
# * **Ineffective Assistance of Counsel (IAC):** Petitioner argues both trial and appellate counsel provided ineffective assistance by failing to raise certain claims and by making strategic errors.
# * **Crawford v. Washington:** Petitioner likely argues that his Sixth Amendment right to confront witnesses was violated, requiring his statements to be suppressed.
# * **Massiah v. United States:** Petitioner likely argues that his Sixth Amendment right to counsel was violated because statements he made were obtained by law enforcement after he had been indicted without his attorney present.
#
# **Precedent:**
#
# * **Strickland v. Washington:** This landmark case establishes the two-pronged test for determining IAC: (1) the lawyer's performance was deficient, and (2) the deficient performance prejudiced the defense.
#
# **Final Judgment:**
#
# * Pending. The court has not yet issued a final judgment in the current appeal.
#
# ## Case History Summary:
#
# This case involves a habeas corpus petition where the petitioner alleges two primary claims:
#
# * **Claim 1:  Crawford Violation:** The petitioner argues that his Sixth Amendment right to confront witnesses was violated under the *Crawford v. Washington* (2004) precedent.
# * **Claim 2: Ineffective Assistance of Counsel:** The petitioner asserts that his attorney was ineffective for waiving his Sixth Amendment right against compelled self-incrimination under the *Massiah v. United States* (1964) doctrine.
#
# **Key Proceedings:**
#
# * **First Habeas Court:**  The first habeas court declined to rule on the merits of the petitioner's claims.
# * **Second Habeas Court:**
#     * A second habeas court, presided over by Judge M. Murphy, held a two-day evidentiary hearing on January 25 and April 18, 2022.
#
# **Pending Matters:**
#
# * The summary does not provide information on the outcome of the second habeas court proceedings or any subsequent appeals.
#
#
# **Note:** This summary is based solely on the provided text and lacks crucial details regarding the specific facts of the case, arguments presented, and the legal reasoning of the courts.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# **Key Legal Arguments:**
#
# * **Petitioner's Argument:** The petitioner argued that his prior habeas counsel was ineffective for failing to:
#     * Raise and argue a *Crawford* violation due to the admission of Marra's testimonial statements without Marra testifying.
#     * Raise and argue a violation of the Sixth Amendment right to counsel stemming from the state's use of Marra to elicit incriminating statements from the petitioner.
#
# * **State's Argument:** The State countered by arguing that the petitioner's expert testimony was not helpful or persuasive and that the petitioner had failed to demonstrate ineffective assistance of counsel.
#
# **Precedents Cited:**
#
# * *Crawford v. Washington*, a landmark Supreme Court case establishing the Confrontation Clause's restrictions on the admission of testimonial hearsay.
# * *Lozada v. Warden*, a Connecticut Supreme Court case recognizing habeas corpus as a remedy for ineffective assistance of appointed habeas counsel.
#
# **Procedural History:**
#
# * The petitioner filed a second habeas corpus petition after his initial petition was denied.
# * This second habeas trial presented testimony from multiple witnesses, including the petitioner's prior habeas counsel, expert witnesses, and the prosecutor in the original criminal trial.
#
# **Final Judgment:**
#
# * The court denied the petitioner's second habeas petition, finding his expert testimony unconvincing and concluding that the petitioner had not proven ineffective assistance of counsel.
# * The petitioner appealed the denial of his habeas petition.
#
#
#
# This summary highlights the key legal arguments, precedents, and procedural history of the *Santaniello v. Commissioner of Correction* case.
#
# ## Case History Summary
#
# * **Issue:**  Petitioner appeals the performance of his counsel during an initial habeas corpus petition, specifically alleging deficiency in failing to argue against the joinder of sexual assault and attempted murder cases for trial.
#
# * **Lower Court Ruling:** The habeas court rejected the petitioner's claim regarding the joinder of cases.
#
# * **Current Appeal:** The petitioner does not contest the habeas court's decision on the joinder issue in the present appeal.
# * **Focus of Appeal:** The appeal centers on the broader challenge to the overall performance of counsel during the initial habeas corpus petition.
#
#
# **Note:** This summary is based solely on the provided document excerpt. Further details regarding the specific arguments and precedents cited in the appeal are needed for a comprehensive legal analysis.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# This case concerns a habeas corpus petition alleging ineffective assistance of counsel.
#
# **Key Legal Arguments:**
#
# * **Ineffective Assistance of Counsel:** The petitioner claims his appointed habeas counsel and trial counsel were ineffective, hindering his ability to receive a fair trial.
#
# * **Strickland v. Washington Test:** The court applies the two-pronged test established in *Strickland v. Washington* to assess the ineffectiveness claims:
#     * **Performance Prong:** The petitioner must demonstrate that counsel's errors were so serious that they were not functioning as the guaranteed counsel under the Sixth Amendment.
#     * **Prejudice Prong:** The petitioner must demonstrate a reasonable probability that, but for counsel's errors, the outcome of the proceeding would have been different.
#
# **Precedents:**
#
# * **Lozada v. Commissioner of Correction:** This case highlights the high burden a habeas petitioner faces in proving ineffective assistance of counsel. The court emphasizes that a habeas petition based on ineffective assistance is inextricably linked to the original conviction.
# * **Lebron v. Commission of Correction:** This case reiterates the *Strickland* test for ineffective assistance of counsel claims, emphasizing that both the performance and prejudice prongs must be satisfied for the petitioner to succeed.
#
# **Final Judgment:**
#
# * The court's decision regarding the petitioner's claims of ineffective assistance of counsel is not provided in the excerpt.
#
#
# **Note:** This summary is based solely on the provided document excerpt and does not reflect the complete case history or final judgment.
#
# ## Case History Summary:
#
# * **Case Name:** _Crocker v. Commissioner of Correction_
# * **Court:** Connecticut Appellate Court
# * **Key Issue:** Habeas corpus petition
#
# * **Legal Arguments:**
#     * The petitioner argued for relief through a habeas corpus petition.
#     * The respondent argued that the petitioner failed to meet the requirements for habeas corpus relief, specifically one or both prongs of a two-pronged test.
#
# * **Precedent:**
#     *  The court cites a previous case  to establish the two-pronged test that petitioners must meet to be successful in a habeas corpus petition.
#
# * **Judgment:**
#     * The court may deny a habeas petitioner's claim if the petitioner fails to satisfy either prong of the established test.
#
#
#
# **Note:** This summary is based solely on the provided excerpt and lacks context regarding the specific facts of the case and the nature of the two prongs in the test.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Key Legal Arguments:**
#
# * **Petitioner's Claim:** The petitioner alleges ineffective assistance of counsel from his attorneys, Randolph and Stevenson, for failing to raise a *Crawford v. Washington* confrontation clause violation related to the admission of out-of-court statements through other witnesses.
# * **State's Argument:** The State argues that the petitioner's claims of ineffective assistance are without merit.
#
# **Precedents Cited:**
#
# * **_Lebron v. Commissioner of Correction_** -  This case establishes that habeas court factual findings are reviewed for clear error, while the application of facts to legal standards is reviewed de novo.
# * **_Crawford v. Washington_** - This case sets forth the requirement that a defendant be afforded the opportunity to confront witnesses against them, including out-of-court statements admitted through other witnesses.
#
# **Final Judgments:**
#
# * **Habeas Court:** The habeas court found that the petitioner failed to demonstrate prejudice arising from the alleged ineffective assistance of counsel.
# * **Appellate Court:** The appellate court upheld the habeas court's findings, concluding that the petitioner's claims were not persuasive.
#
#
# **Additional Notes:**
#
# * The appellate court focused on the petitioner's burden to demonstrate prejudice resulting from the alleged ineffective assistance of counsel.
# * The court's analysis appears to hinge on the petitioner's inability to show that a new trial would have been granted had the *Crawford* claim been raised.
#
#
# This case history provides a concise overview of the key legal arguments, precedents, and judgments in  _Santaniello v. Commissioner of Correction_.
#
# ## Case History Summary
#
# **Key Arguments:**
#
# * **Petitioner's Claim:** The petitioner argues that a new trial is warranted due to the trial court's failure to consider a *Crawford* claim regarding the admission of certain evidence.
# * **Respondent's Argument:** The respondent contends that the petitioner failed to demonstrate prejudice from the alleged error, as it is unclear whether the trial court would have granted a new trial based on a *Crawford* claim.
#
# **Precedent:**
#
# * The court relies on the precedent established in *Crawford v. Washington* (2004), which addresses the admissibility of testimonial hearsay evidence.
#
# **Final Judgment:**
#
# * The court denies the petitioner's request for a new trial.
# * The court finds that the petitioner has not proven prejudice arising from the alleged *Crawford* violation.
# * The court also finds that it is unclear whether the petitioner would have prevailed on appeal had a *Crawford* claim been raised.
#
#
# **Analysis:**
#
# The court's decision hinges on the petitioner's inability to demonstrate prejudice resulting from the alleged *Crawford* error. The court's reasoning suggests that the petitioner must not only establish a *Crawford* violation but also demonstrate a reasonable probability that the outcome of the trial would have been different had the violation been addressed.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Facts:**
#
# * The petitioner, Santaniello, was convicted of sexual assault and attempted murder.
# * The state presented evidence including:
#     * Photos of the victim's injuries
#     * The victim's clothing, including a shirt, sweatpants, and underwear
#     * Testimony from the victim's roommate corroborating the victim's account of the assault
#
# **Legal Arguments:**
#
# * Santaniello's habeas corpus petition alleged ineffective assistance of counsel.
# * The petitioner argued that his attorney's performance was deficient because he failed to adequately object to the admission of certain evidence, specifically exhibit 3 (photo of the victim's injury), exhibit 8 (the victim's shirt), exhibit 6 (victim's sweatpants), and exhibit 7 (victim's underwear).
#
# **Precedents:**
#
# * The court cited *Delgado v. Commissioner of Correction* to establish the standard for proving prejudice in an ineffective assistance of counsel claim. The *Delgado* case held that a petitioner must demonstrate a "reasonable probability" that the result of the proceeding would have been different but for counsel's errors.
#
# **Judgment:**
#
# * The habeas court found that Santaniello failed to meet the burden of proving prejudice.
# * The court held that the petitioner had not shown that there was a reasonable probability that the outcome of the trial would have been different if his attorney had objected to the admission of the evidence.
#
#
# **Note:** This summary is based on the provided excerpt and may not capture the full complexity of the case.
#
# ## Case History Summary:
#
# This case involves a habeas petition alleging ineffective assistance of appellate counsel.
#
# **Key Arguments & Precedents:**
#
# * **Petitioner's Claim:** The petitioner argues that appellate counsel was ineffective in failing to raise a specific claim (likely the Crawford claim) on direct appeal.
# * **State's Defense:** The state argues that appellate counsel was not deficient in failing to raise the claim and that, in any event, the petitioner has not shown prejudice.
# * **Relevant Legal Standard:** The court applies the two-pronged test from *Strickland v. Washington* to assess ineffective assistance of counsel claims:
#     * **Deficiency:** The petitioner must show that counsel's performance fell below an objective standard of reasonableness.
#     * **Prejudice:** The petitioner must show that there is a reasonable probability that, but for counsel's errors, the result of the appeal would have been different.
# * **Precedent Cited:** The court cites *Crocker v. Commissioner of Correction* to emphasize that both prongs of the *Strickland* test must be satisfied for a habeas petitioner to prevail.
#
# **Final Judgment:**
#
# * The court finds that the petitioner failed to prove that appellate counsel was deficient in failing to raise the Crawford claim.
# * Consequently, any alleged error by the court regarding the prejudice prong is deemed harmless.
# * The court denies the petitioner's habeas claim.
#
#
#
#  **Note:** This summary is based solely on the provided excerpt and may not capture the full complexity of the case.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# This case involves a criminal prosecution for attempted murder and sexual assault.
#
# **Key Legal Arguments:**
#
# * **State:**  The State presented evidence of the victim's testimony, her roommate's account, and forensic evidence linking the petitioner's DNA to the crime scene. They also relied on the testimony of prison officials and fellow inmates who corroborated the petitioner's knowledge of the victim and his desire to have her killed.
# * **Petitioner:**  The petitioner's defense likely focused on challenging the credibility of the victim's testimony and the reliability of the forensic evidence. They may have also attempted to discredit the testimony of the prison officials and inmates, arguing that their accounts were unreliable or motivated by other factors.
#
# **Precedent:**
#
# The summary does not explicitly mention any specific legal precedents relied upon by either party. However, the case likely involved general principles of criminal law, such as:
#
# * **Burden of Proof:** The State bore the burden of proving the petitioner's guilt beyond a reasonable doubt.
# * **Hearsay:** The admissibility of the victim's roommate's testimony and statements made by the petitioner to fellow inmates would have been subject to hearsay rules.
# * **Confessions:** The voluntariness of the petitioner's statements to law enforcement would have been crucial to their admissibility as evidence.
#
# **Final Judgment:**
#
# The provided text excerpt does not disclose the final judgment in the case.
#
#
# **Note:** This summary is based on limited information. A complete and accurate legal analysis would require reviewing the entire case record, including pleadings, motions, trial transcripts, and any appellate decisions.
#
# ##  Case History Summary: Santaniello v. Commissioner of Correction
#
#  **Parties:**
#
# *  Petitioner: Santaniello
# *  Respondent: Commissioner of Correction
#
# **Case Background:**
#
# * This case involves a challenge to the admission of evidence at Santaniello's criminal trial.
#
# **Key Legal Arguments:**
#
# * **Petitioner:**  Arguing that the admission of certain evidence violated his due process rights. Specifically, he claims that a news report and correspondence between himself and Marra were improperly used against him.
# * **Respondent:** Likely arguing that the evidence was admissible and relevant to Santaniello's criminal charges.
#
# **Precedent:**
#
# * The specific legal precedents relied upon by both parties are not explicitly mentioned in the provided text.
#
# **Witnesses:**
#
# *  **Holeman:** Testified that a news report only showed Santaniello's name and face, and did not include details he shared.
# * **Nobile:**  Testified about receiving a letter from Marra indicating a desire to have a witness killed in a major criminal case. Nobile also testified about a subsequent meeting with Marra where Marra provided Santaniello's name and a letter from Santaniello to Marra.
#
# **Evidence:**
#
# * **Exhibit 14:** Letter from Marra to Nobile stating his desire to have a witness killed and offering to provide identifying information for a fee.
# * **Exhibit 12:** Letter from Santaniello to Marra, the content of which is not fully detailed in the text, but Nobile found two specific elements significant.
#
# **Final Judgment:**
#
# * The text does not provide information about the final judgment in this case.
#
#
# **Note:** This summary is based solely on the provided text. For a complete understanding of the case, further legal documents and context are required.
#
# ##  Case History Summary:
#
# This excerpt focuses on testimony regarding a letter ("Exhibit 12")  central to a legal case.
#
# * **Witness Testimony:** Nobile, a witness, testified about the significance of a letter ("Exhibit 12") found after an individual's return home.
# * **Key Elements:**
#     * **"Donna's #":**  Nobile claims Marra (an individual involved in the case) indicated "Donna" referred to the victim in the case.
#     * **"Joe":** Nobile further states that Marra identified "Joe" as a shortened form of "Joe Black" and connected it to the petitioner (likely the party initiating legal action).
#
# * **Legal Implications:** The testimony aims to connect the petitioner ("Joe Black") to the victim ("Donna") through the letter.  The context suggests potential involvement in a crime or dispute, with the letter serving as evidence.
#
# * **Missing Information:**  The specific nature of the legal action, the charges or claims, and the opposing party's arguments are not provided in this excerpt.
#
#
# This summary highlights the crucial testimony and its potential legal implications within the broader case. More information is needed to fully analyze the legal arguments, precedents, and final judgment.
#
# ## Santaniello v. Commissioner of Correction: Case Summary
#
# **Key Legal Arguments:**
#
# * **Prosecution:**  The prosecution relied on the testimony of Correctional Officer Nobile and informant Dillon, who presented evidence of letters written by the petitioner (Santaniello) using coded language referencing the victim and her property.
# * **Defense:**  The defense likely challenged the admissibility of the letters and phone call recording, arguing lack of probable cause for the informant's involvement or potential coercion of the informant.
#
# **Precedents:**
#
# *  The case likely involved precedent regarding the admissibility of:
#     * **Informant Testimonies:**  Courts often scrutinize informant testimonies for reliability and potential bias.
#     * **Covert Communications:**  The use of coded language in letters and phone calls may raise questions about its interpretation and admissibility as evidence.
#
# **Final Judgment:**
#
# *  The provided text excerpt does not reveal the final judgment in the case.
#
# **Additional Notes:**
#
# *  The excerpt highlights the investigative steps taken by Nobile and Dillon, including confirming the victim's identity and researching the meaning of the alias "Joe Black."
# *  The mention of a phone call recording suggests that the prosecution sought to use recorded conversations between the petitioner and Marra as evidence.
# *  To obtain a complete understanding of the case, further legal documents outlining the trial proceedings, arguments, and final judgment would be required.
#
# ## Case History Summary: Dillon's Testimony
#
# * **Testimonial Evidence:**  Witness Dillon testified that he independently investigated the victim and acquired information regarding their address, vehicle type, and license plate number.
# * **Envelope Corroboration:** Dillon further stated that the address listed on an envelope associated with the case matched the victim's confirmed address.
#
# **Significance:** This testimony provides circumstantial evidence potentially linking Dillon to the victim and suggesting knowledge of their personal details. The matching address on the envelope strengthens the credibility of Dillon's investigation and his potential involvement.
#
#
# Please note: This summary is based solely on the provided document excerpt and lacks context regarding the broader case.  A comprehensive legal analysis would require reviewing the entire case file and relevant legal precedents.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# This case involves a dispute regarding alleged communication between an inmate (Santaniello) and an individual (Nobile) posing as an undercover assassin.
#
# **Key Legal Arguments:**
#
# * **Prosecutor's Argument:** The prosecution likely argued that the inmate's communication with "Tommy's friend" constituted a solicitation for murder, a serious criminal offense. They may have relied on the content of the voice message and the inmate's subsequent interactions with Nobile to establish this argument.
# * **Defendant's Argument:** The defense likely contested the prosecution's interpretation of the communication, arguing that it was innocuous or lacked the necessary elements to constitute a criminal solicitation. They may have focused on the context of the conversation, the inmate's intent, and the lack of concrete actions taken towards carrying out a murder plot.
#
# **Precedent:**
#
# ...
#
# * **Legal Standard:** The court applies a de novo standard of review to the question of agency, meaning it independently examines the legal arguments and applicable facts.
#
# * **Evidentiary Scope:** The court's review is not limited to the trial court's factual findings. It may consider all undisputed facts established in the record, including evidence presented at trial.
#
# * **Precedent:** The court cites *State v. Ashby*, 336 Conn. 452, 247 A.3d 521 (2020), which establishes the de novo standard of review for legal questions regarding agency relationships in similar contexts.
#
# * **Final Judgment:**  The summary does not disclose the final judgment of the court regarding the admissibility of the evidence.
#
#
# Please note: This summary is based solely on the provided document excerpt and lacks information about the full case history, arguments from both sides, and the ultimate outcome.
#
# ##  Case History Summary: Santaniello v. Commissioner of Correction
#
# This case revolves around a potential violation of the Sixth Amendment right to counsel as established in *Massiah v. United States, 377 U.S. 201 (1964)*.
#
# **Key Legal Arguments:**
#
# * **Petitioner's Claim:** The petitioner alleges that his Sixth Amendment right to counsel was violated because a government agent, acting without his counsel's presence, deliberately elicited incriminating statements from him after he had been indicted.
#
# * **State's Defense:** The state likely argues that the informant was not acting as an agent of the government or that the interaction did not constitute a deliberate attempt to elicit incriminating statements.
#
# **Relevant Precedents:**
#
# * **Massiah v. United States, 377 U.S. 201 (1964):** Established that a state violates the Sixth Amendment when it elicits incriminating statements from a defendant after indictment and the right to counsel has attached, through an undisclosed agent.
# * **State v. Swinton, 268 Conn. 781, 847 A.2d 921 (2004):**  Reinforces the state's affirmative obligation to respect a defendant's right to counsel.
# * **State v. Ashby, 336 Conn. 452, 247 A.3d 521 (2020):**  Provides guidance on proving a Sixth Amendment violation under *Massiah*, requiring proof of: (1) attachment of the Sixth Amendment right to counsel, (2) government agent acting without counsel present, and (3) deliberate elicitation of incriminating statements.
#
# **Determining Agency Relationship:**
#
# Courts consider factors like:
#
# * Informant's motivation (reward vs. self-motivation).
# * Police instructions to the informant (e.g., obtaining incriminating evidence).
# * Government's pre-existing plan involving the informant.
#
# **Final Judgment:**
#
# The summary does not provide information about the final judgment in this case. It merely outlines the legal framework and arguments involved.
#
# Please provide me with the full legal document or the context surrounding "Legal Document Chunk 85".  The provided snippet is incomplete and lacks crucial information to construct a meaningful case history.
#
# To create a comprehensive summary, I need the complete text of the legal document, including:
#
# * **Case Name and Citation:** This identifies the specific case.
# * **Parties Involved:** Who are the plaintiffs and defendants?
# * **Factual Background:** What are the key events leading to the legal dispute?
# * **Legal Issues:** What are the specific legal questions being addressed?
# * **Arguments Presented:** What are the legal arguments made by each side?
# * **Precedent Cited:** Which previous court decisions are used to support the arguments?
# * **Court's Reasoning:** How did the court analyze the arguments and apply the law?
# * **Final Judgment:** What was the court's decision and its rationale?
#
#
# Once I have this information, I can provide you with a clear and structured legal summary.
#
# ## Santaniello v. Commissioner of Correction: Case History Summary
#
# **Case Details:**  Santaniello appeals his conviction, alleging the state improperly used jailhouse informant Marra's testimony.
#
# **Key Legal Arguments:**
#
# * **Petitioner:** Argues despite no express request or promise, Marra's history as a jailhouse informant, meetings with law enforcement beyond the current case, and shared attorney with the state imply an implicit agency relationship between Marra and the state. This relationship, the petitioner claims, makes Marra's testimony tainted and inadmissible.
# * **Respondent:**  Likely argues that Marra was not a state agent but an independent informant who chose to provide information. The lack of explicit direction or promise of benefit would support this argument.
#
# **Precedent:**
#
# * **Nobile v. State:**  Nobile testified that he accompanied an inspector to interview Marra about a homicide case unrelated to Santaniello's case. This demonstrates Marra's prior involvement with law enforcement.
# * **State v. Tomasko:** Marra's involvement in this case was discussed by the Supreme Court, highlighting his history of providing information to police on various subjects.
#
# **Final Judgment:**
#
# *  The outcome of Santaniello's appeal is not provided in this document excerpt.
# *  The court will likely analyze the nature of Marra's relationship with the state, considering his past experiences and the circumstances surrounding his testimony in Santaniello's case.
# *  The court will determine if Marra's testimony was obtained in a way that violated Santaniello's constitutional rights.
#
#
# This summary highlights the key legal arguments and precedents involved in Santaniello's appeal. The final judgment regarding the admissibility of Marra's testimony and its impact on Santaniello's conviction remains unknown based on the provided document excerpt.
#
# ## Case History Summary
#
# This excerpt from a legal document suggests the following:
#
# * **Witness Testimony:** The witness ("he") stated that he had multiple interviews with various police officials beginning in October 1985.
# * **Subject Matter:** The interviews covered a range of subjects, including "a number of subjects" and "more than twenty homicides."
# * **Implication:** This testimony suggests the witness may have been a person of interest or a potential source of information in multiple homicide investigations.
# * **Further Context Needed:**  To provide a more comprehensive case history, additional information is required, such as:
#     * **Identity of the Witness:**  Who is "he"?  Is he a suspect, a victim, a witness to a crime, or someone else?
#     * **Nature of the Interviews:** Were the interviews formal interrogations or informal conversations?
#     * **Outcome of the Interviews:** Did the interviews lead to any charges, arrests, or convictions?
#
#
# Without further context, it is impossible to determine the legal significance of this testimony or its impact on any potential case.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Key Legal Arguments & Precedents:**
#
# * **Petitioner's Argument:** The petitioner argues that past interactions between the state and a jailhouse informant (Marra) constituted a tacit agreement where Marra acted as an agent of the state, thus violating the petitioner's Sixth Amendment right to counsel as established in *Massiah v. United States*. The petitioner relies on *United States v. Brink* (3rd Cir. 1994) to support this argument.
# * **State's Argument:** The state distinguishes the present case from *Brink*, highlighting the lack of any express directive from law enforcement to Marra regarding the petitioner. The state argues that the facts are more akin to *State v. Swinton* (Conn. Sup. Ct. 2002), where a similar *Massiah* claim was rejected.
#
# **Key Facts:**
#
# * Prior to September 4, 2002, there was no indication of law enforcement directing Marra to interact with the petitioner.
#
# **Final Judgment:**
#
# * The court likely denied the petitioner's *habeas corpus* claim, finding that the facts did not support a *Massiah* violation. The court likely relied on the lack of express direction from law enforcement to Marra and found the facts more aligned with *Swinton* than *Brink*.
#
#
# **Note:** This summary is based on the provided excerpt and may not reflect the full legal arguments and rulings in the case.
#
# Please provide me with the full legal documents so I can accurately summarize the case history for you.
#
# The excerpt you've given mentions a court case and cites a previous ruling ("Id., 854").  To create a comprehensive and helpful summary, I need the complete text of the documents, including:
#
# * **The names of the parties involved**
# * **The court that issued the decision**
# * **The factual background leading to the case**
# * **The specific legal arguments presented by both sides**
# * **The court's reasoning and analysis**
# * **The final judgment and any relevant legal precedents cited**
#
#
# Once I have this information, I can provide you with a clear and concise legal summary in the format you requested.
#
# ## Case Summary: Santaniello v. Commissioner of Correction
#
# **Key Legal Arguments:**
#
# * **Informant Status:** The petitioner argued that the informant, Marra, was an agent of the state due to his past cooperation with law enforcement in unrelated matters.
# * **Lack of Direction:** The respondent countered that Marra was not acting as an agent because there was no evidence the police directed him to gather information specifically about the petitioner or offered him any rewards for doing so.
#
# **Precedent:**
#
# * The court cited *State v. Brown*, 856 A.2d 856 (Conn. App. Ct. 2004), where a similar argument regarding informant status was rejected. The court in *Brown* held that prior cooperation in unrelated investigations did not automatically transform an informant into an agent.
#
# **Evidence:**
#
# * The petitioner's criminal trial evidence showed that Marra initiated contact with the state regarding the petitioner.
# * The state presented testimony from law enforcement officers stating they never asked Marra to collect information on the petitioner and that no benefits were promised or given in exchange for his assistance.
# * Marra's Department of Correction file, with voluntary statements made after September 2002,  supported the lack of a preexisting relationship with law enforcement.
#
# **Final Judgment:**
#
# *  The court sided with the respondent, finding that Marra was not acting as an agent of the state and that his actions did not violate the petitioner's constitutional rights.
#
#
# The court emphasized the importance of clear direction and incentivization by law enforcement in determining whether an individual qualifies as an agent.  In this case, the lack of  evidence demonstrating such involvement meant Marra was considered a private citizen, not a state agent.
#
# ## Case Summary:  Lasaga (269 Conn. 454, 848 A.2d 1149 (2004))
#
# **Key Facts:** A private citizen provided information to law enforcement. The petitioner argued that the citizen acted as a state agent because of certain circumstances.
#
# **Legal Arguments:**
#
# * **Petitioner's Argument:** The private citizen acted as a state agent due to the circumstances surrounding the information sharing.
# * **Court's Response:** The court rejected the petitioner's argument, citing the case of Lasaga, which established that a private citizen is not a state agent unless promised or provided with a benefit in exchange for information.
#
# **Precedent:**
#
# * **Lasaga, 269 Conn. 454, 466, 848 A.2d 1149 (2004):** This case established the principle that a private citizen is not considered a state agent simply for providing information to law enforcement, unless a benefit is offered or received in exchange.
#
# **Judgment:**
#
# * The court ruled that the private citizen was not acting as a state agent and therefore, the petitioner's argument was dismissed.
#
#
#
#  **Note:** This summary is incomplete as the provided document fragment does not detail the full context of the case, including the specific circumstances surrounding the citizen's actions and the petitioner's full arguments.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# **Key Legal Issue:**  Violation of the defendant's Sixth Amendment right against self-incrimination (Massiah claim) due to alleged improper communication with a co-inmate who later testified against him.
#
# **Facts:**
#
# * The defendant (Santaniello) was a pretrial detainee.
# * A fellow inmate (Marra) had contact with law enforcement and provided information about Santaniello.
# * Santaniello's attorney (Randolph) pursued a Massiah claim, arguing that Marra's conversations with Santaniello were coerced by the government and violated his rights.
# * The trial court suppressed some of Santaniello's statements to Marra made after a specific date, but allowed others.
#
# **Legal Arguments:**
#
# * **Santaniello:** The placement of Marra in Santaniello's cell was purposeful and constituted government-induced communication, violating his Sixth Amendment right against self-incrimination.
# * **Randolph:**  While a Massiah claim was raised, the evidence did not support a claim that Marra's placement was purposeful.  The decision to limit the suppression motion was a strategic one based on the available evidence.
#
# **Precedents:**
#
# * The court cited *United States v. Brink*, 39 F.3d 424, which established that the government's placement of an informant in a cell with an inmate raises concerns about potential Sixth Amendment violations.
#
# **Judgment:**
#
# * The court found that Randolph's pursuit of the Massiah claim, though limited, was not objectively unreasonable given the evidence available at the time.
# * The court upheld the trial court's decision to suppress some of Santaniello's statements to Marra, while allowing others based on the specific facts and circumstances.
#
#
#
# Let me know if you need further clarification or have any other legal documents you'd like me to analyze.
#
# ## Case History Summary:
#
# * **Issue:** The defendant argues that the trial court erred in limiting the scope of a Massiah challenge based on evidence of pre-September 4, 2002 actions by the defendant.
# * **Argument:** The defendant claims that this limitation prejudiced their right to a fair trial.
# * **Court's Reasoning:** The court found that the decision to limit the Massiah challenge was a matter of trial strategy.
# * **Precedent:** The court cited its own previous decisions declining to review trial strategy choices.
# * **Judgment:** The court upheld the trial court's decision, finding no reversible error in limiting the Massiah challenge based on the presented evidence.
#
#
# **Note:**  This summary is based solely on the provided text fragment. A complete understanding of the case requires review of the full legal documents.
#
# ## Case History: Santaniello v. Commissioner of Correction
#
# * **Nature of Case:** Habeas corpus petition alleging ineffective assistance of counsel.
# * **Key Issue:** Whether trial counsel was deficient for failing to raise a *Massiah* claim regarding a pre-trial statement made by the petitioner to a police officer.
# * **Legal Argument:** The petitioner argued that his counsel was ineffective because they did not pursue a broader *Massiah* challenge to the admission of the pre-trial statement.
# * **Precedent:** The court relied on the *Massiah* v. United States (1964) precedent, which establishes that the Sixth Amendment protects a defendant's right to counsel during custodial interrogation, and that any statements made to law enforcement without counsel present are inadmissible.
# * **Court Finding:** The habeas court and the appellate court both concluded that trial counsel was not deficient in failing to raise a more expansive *Massiah* challenge.  The courts found that the circumstances did not warrant such a claim.
# * **Judgment:** The judgment of the habeas court was affirmed.
#
#
# **Note:** This summary is based solely on the provided excerpt and may not capture the full context of the case.

# %% [markdown]
# #### ***Step 2: Legal Intelligent (AI) Chat Bot - RAG Based***

# %% [markdown]
# #### ***Training Trough System Prompt***

# %%
#llm_groq = ChatGroq(model_name="llama 3B", api_key=os.getenv("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"))
llm_groq = ChatGroq(model_name="mixtral-8x7b-32768", api_key=os.getenv("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"))

# %%
system_prompt = SystemMessage(
    content=(
       """You are a legal assistant AI specialized in providing clear, concise, and structured legal responses. When answering legal questions, follow these guidelines:
          Provide a Direct Answer: Start with a clear and factual response.
          Don't directly start answers. Start off with the Questions context
          Offer Context if Needed: Briefly explain relevant legal concepts or context.
          Structure Your Response: Use bullet points, numbered lists, or headings to ensure clarity.
          Reference Legal Outcomes: If applicable, mention verdicts, judgments, or rulings.
          Stay Objective and Professional: Maintain a neutral tone and avoid unnecessary opinions.
          Example:
          User: What was the final verdict given by the Gwinnett County jury?
          Answer: The final verdict given by the Gwinnett County jury was that
committing a violent injury upon him or by committing an act which placed the victim
in reasonable apprehension of immediately receiving a violent injury. In a consolidated
order on all pre-trial motions, the trial court denied Galvez’s demurrer.
"""
    )
)

# %% [markdown]
# #### ***Retrieving Embeddings from Chroma DB for AI Chat Bot***

# %%
retriever = vector_db.as_retriever()
qa_chain = RetrievalQA.from_chain_type(llm=llm_groq, retriever=retriever, chain_type="stuff")

# %% [markdown]
# #### ***Step 3: FAQs Storage***

# %%
#### _Step 3 is embedded part of Step 2_
faq_store = {}

def get_faq_answer(query):
    return faq_store.get(query.lower())

def store_faq(query, answer):
    if len(faq_store) >= 10:
        faq_store.pop(next(iter(faq_store)))
    faq_store[query.lower()] = answer

# %%
###Process User Queries (Legal AI Chatbot)
def ask_legal_question(query):
    """Handles user queries for legal information."""

    # Check if the question exists in FAQs
    faq_answer = get_faq_answer(query)
    if faq_answer:
        return f"FAQ Answer: {faq_answer}"

    # Search in vector database (Retrieve case laws)
    response = retriever.get_relevant_documents(query)
    if response:
        return f"Analysing 📄:\n{response[0].page_content}"

    # If no relevant document is found, use LLM for general legal knowledge
    print("No relevant document found, using 🔍 ")
    response_text = llm_groq.invoke([system_prompt, HumanMessage(content=query)])

    # Store the query-answer pair in FAQ
    store_faq(query, response_text.content)

    return response_text.content

# %%
def chatbot():
    """Runs the AI-powered legal chatbot."""
    print("🔹 Legal AI Chatbot (Type 'exit' to stop) 🔹")
    user_query = input("\nUser: ")
    print(user_query)
    if user_query.lower() != "exit":
        response = ask_legal_question(user_query)
        print(f"Legal Bot: {response}")

# Run Chatbot
chatbot()
# Out:
# 🔹 Legal AI Chatbot (Type 'exit' to stop) 🔹
#
# User: What was the final verdict given by the Gwinnett County jury?
# What was the final verdict given by the Gwinnett County jury?
# Legal Bot: Analysing 📄:
# committing a violent injury upon him or by committing an act which placed the victim
# in reasonable apprehension of immediately receiving a violent injury. In a consolidated
# order on all pre-trial motions, the trial court denied Galvez’s demurrer.
# After a trial, Gwinnett County jury found Galvez guilty on Counts 3 and 6. With
# respect to Count 2, the jury found Galvez not guilty of felony murder, but guilty of the
# lesser-included offense of voluntary manslaughter. Galvez was acquitted on the
# remaining counts. Galvez filed a motion for new trial, as amended. The trial court
# denied the motion for new trial after a hearing, and this appeal followed.
# 1. Galvez first argues that the trial court erred by overruling his demurrer to the
# indictment. Specifically, he points out that in Count 3 of the indictment, the State
# 1 Count 4 of the indictment charged him with committing aggravated assault by
# pointing a firearm at the victim’s head.
# 4
